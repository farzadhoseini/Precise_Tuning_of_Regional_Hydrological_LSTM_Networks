# %% [markdown]
# # Systematic HyperParameters Tuning (SHPsT) with Random Search for Hydrological Prediction using LSTMs
#
# This code is for paper: "Precise Tuning of Regional Hydrological LSTM Networks: Simultaneous Systematic Random Search Optimization" by Hosseini et al. (in review)
#
# # Overview
#
#         This code outlines a systematic hyperparameter tuning approach using random search, specifically tailored for hydrological prediction using LSTMs. While the example focuses on Multi-Timescale LSTM (MTS-LSTM), the methodology can be adapted for other Deep Learning models.
#
# **Steps**
#
# 1. Hyperparameter Space Definition
#
#         Description: Define the hyperparameters, specifying their ranges and values for simultaneous tuning.
#         Details: In this study, 12 hyperparameters were chosen for tuning, as detailed in the associated paper.
#
# 2. Random Search Training and Verification
#
#         Description: Execute random searches within the predefined hyperparameter space.
#         Details:
#         Initial Configuration: 1000 randomly tuned configurations.
#         Two Sequential Sets of Searches:
#         100 runs
#         All 1000 configurations
#         Note: While 100 searches often yield acceptable high accuracy for several basins, increasing the search count can improve predictions, especially for regional models. However, more searches increase computational costs, necessitating a resource-conscious decision.
#
# 3. Analysis of Verification Metrics
#
#         Description: Analyze the results to identify optimal hyperparameter configurations.
#         Details:
#         Post-Random Sraech DATASET Structure:
#         Configurations: 100 (74 successful) or 1000 (594 successful) lines
#         Basins: Every configuration results in 25 distinct NSE and KGE metrics for 25 basins with verification data; later we tested final hyper-tuned models' performance on all 40 basins.
#         Metrics: KGE and NSE values for each basin
#         Analysis Approach:
#         Regional Analysis: Averaging metrics across all basins for each configuration (We used this method to select final best-performing configurations)
#         Catchment-scale Analysis: Evaluating each basin individually (This method could help to have more catchment-wise configurations)
#         Outcome: The best-performing configuration was selected based on the highest average NSE and KGE metrics across all 25 basins after both 100 and 1000 random searches.
#
# 4. Training the Best-Performing Models
#
#         Description: Train the models with the top-performing configurations identified from the random search.
#         Models:
#         Regional Optimal (RO): Best-performing configuration after 100 random searches
#         Enhanced Regional Optimal (ERO): Best-performing configuration after 1000 random searches
#         Training Runs: Conduct 10 training runs using 10 different random seeds for each selected configuration (RO and ERO).
#         Outcome: Each model produces an ensemble of 10 predictions, accompanied by their respective metrics for each catchment.

# %%
"""
=================== Import required libraries ===================
"""
import csv
import ast
import os
import yaml
import pickle
import shutil
import random
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib import colors
import matplotlib.patches as mpatches

from pathlib import Path
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import sys
sys.path.append(r'C:\Users\hosseinifh\neuralhydrology') # In case of using VSC, this can help to activate and run libraries installed
# In our experiments we employed NeuralHydrology Python Library (Kratzert et al., (2022). NeuralHydrology --- A Python library for Deep Learning research in hydrology. 
# Journal of Open Source Software, 7(71), 4050, https://doi.org/10.21105/joss.04050)

from neuralhydrology.nh_run import start_run, Config
from neuralhydrology.evaluation import metrics, get_tester
from neuralhydrology.nh_run_scheduler import schedule_runs
from sklearn.model_selection import train_test_split
from pandas.plotting import parallel_coordinates
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import ParameterGrid, ParameterSampler
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## Random Search Setup
#
#     Ensuring the randomness and uniformity of the random search algorithm is crucial for effective hyperparameter tuning. Here's how we addressed this in our approach:
#
# # Parameter Grid Design
#
#     Objective: Cover the entire range of values within the hyperparameter space.
#     Implementation:
#     We designed a diverse grid for each hyperparameter based on consultations and initial trial and error.
#     Recommendation: Before applying this approach to a new dataset, researchers are advised to conduct manual trials on select basins to determine an appropriate hyperparameter space for their regional model.
#
# # Random Sampling Mechanism
#
#     Objective: Achieve uniform sampling across the hyperparameter space.
#     Implementation:
#     We utilized ParameterSampler from scikit-learn's model_selection module.
#     This mechanism ensures each hyperparameter combination is selected with equal probability, maintaining randomness and uniformity.
#
# # Number of Samples
#
#     Objective: Generate sufficient samples to explore the hyperparameter space adequately.
#     Implementation:
#     We set the number of samples to n_samples = 1000, considering the size and complexity of the hyperparameter grid.
#
# # Independent Sampling
#
#     Objective: Ensure each hyperparameter combination is sampled independently.
#     Implementation:
#     ParameterSampler was employed to sample each hyperparameter independently, preserving the randomness and uniformity of the sampling process.
#
# ## Code for Generating Random Configurations
#
#     The following code generates 1000 random hyperparameter configurations for the models to be trained in subsequent steps. This approach provides a broad exploration of the hyperparameter space.
#
# # Considerations for Customization
#
#     Initial Exploration:
#     You can begin with a smaller number of random searches and evaluate the verification outcomes.
#     This allows for a more focused selection of hyperparameter configurations by narrowing down the hyperparameter space based on the observed performance.
#
# # Replicating the Experiment
#
#     Note: To replicate our exact experiment, please run the generated random configurations available in the supplementary folder.
#     Recommendation for flexibility:
#     While our code provides a specific set of random configurations, we encourage researchers to experiment with varying levels of randomness to potentially discover optimized configurations for their specific datasets and models.

# %%
"""
============= Code to create random configs ===================
"""

# Create a new folder for the config files
config_folder = Path("Config_Hypertuning_files")
config_folder.mkdir(exist_ok=True)

# Define the hyperparameter grid for random search
param_grid = {
    'hidden_size': [16, 32, 64, 128, 256],
    'initial_forget_bias': [-3, -1, 0, 1, 3],
    'output_dropout': [0, 0.2, 0.4],
    'batch_size': [32, 64, 128, 256],
    'learning_rate': [{0: lr_1, 10: lr_2, 25: lr_3} for lr_1 in [1e-3, 1e-2, 5e-2]
                      for lr_2 in [5e-4, 1e-3, 5e-3] for lr_3 in [1e-4, 1e-3]],
    'target_noise_std': [0, 0.01, 0.02, 0.05, 0.1],
    'loss': ['NSE', 'RMSE'], # {1, 2}
    'regularization': ['tie_frequencies', None], # {1, 0}
    'seq_length': [{'1D': length_1, '1H': length_2} for length_1 in [146, 182, 365, 730, 1095]
                   for length_2 in [168, 336, 504, 672, 1344, 2016, 4032, 6720, 8064, 8760]],
}

# Specify the number of random samples to generate
n_sample = 1000

# Create a sampler to generate random hyperparameters
param_sampler = ParameterSampler(param_grid, n_iter=n_sample)

# Create an empty dictionary to store the results
results = {}
output_results = {}

# Loop through each set of hyperparameters
for i, params in enumerate(param_sampler):
    try:
        # Create a new configuration file with a unique name based on the current set of hyperparameters
        config_file = config_folder / Path(f"Config_Hypertuning_{i}.yml")

        # Load the original configuration file and create a copy
        config = yaml.load(Path("config_mts_LSTM.yml").read_text(), Loader=yaml.SafeLoader) # (...\Supplementary_materials)
        config_copy = config.copy()

        # Update the copy with the current set of hyperparameters
        config_copy.update(params)

        # Write the updated configuration to the new file
        config_file.write_text(yaml.dump(config_copy, default_flow_style=False))

    except Exception as e:
        print(f"Error occurred for params {params}: {e}")
        continue  # continue to the next set of hyperparameters

print("Config files have been created and saved in the Config files folder")
# Out:
# Config files have been created and saved in the Config files folder

# %%
"""
============= Code to Run multiple trainings in parallel by NeuralHydrology Python library ===================
"""

config_folder = Path("Config_Hypertuning_files_paper_experiment")

# Set the mode, directory, GPU IDs, and runs per GPU
mode = "train"
directory = config_folder
gpu_ids = [0, 1]  # List of GPU IDs to use (We had 2 GPUs cluster with 7 CPUs)
runs_per_gpu = 5  # Number of runs to start on a single GPU depending on the resources. We could not increase to more than 5.

try:
    # Call the schedule_runs function
    schedule_runs(mode, directory, gpu_ids, runs_per_gpu)

except Exception as e:
    print(f"An error occurred during execution: {e}")

# %%
"""
=================== After hypertuning finished and we want to only read folders ===================
                        Extracting Hyperparameters and validation results
"""

# Define the parent directory that contains the folders with config files
parent_dir = r'...\Supplementary_materials\Hypertuning' 
# Since 1000 Randomly trained models are too much data, we could not upload them all but after you run hypertuning, can use the following code to extract results from your experiment.

# Set the directory for the results
results_dir = Path(r'...\Supplementary_materials\Results')

# Define the list of parameters to extract from the config files
params = {
    'hidden_size',
    'initial_forget_bias',
    'output_dropout',
    'batch_size',
    'learning_rate',
    'target_noise_std',
    'regularization',
    'seq_length',
    'loss',
    'seed'
}

# Create an empty dictionary to store the results
hyperparameters_list = []

# Iterate over the folders in the parent directory
for folder_name in os.listdir(parent_dir):
    # Create the path to the folder
    folder_path = os.path.join(parent_dir, folder_name)
    # Check if the path is a directory
    if os.path.isdir(folder_path):
        # Create an empty dictionary to store the hyperparameters for this folder
        hyperparameters = {}
        # Read the config file for this folder
        try:
            config_path = os.path.join(folder_path, "config.yml")
            with open(config_path, "r") as f:
                config = yaml.safe_load(f)
            # Extract the relevant hyperparameters from the config file
            for param in params:
                if param in config:
                    if param == 'learning_rate':
                        # Extract the individual learning rate values and add them as separate columns
                        lr_dict = config[param]
                        hyperparameters["Lr0"] = lr_dict.get(0, None)
                        hyperparameters["Lr10"] = lr_dict.get(10, None)
                        hyperparameters["Lr25"] = lr_dict.get(25, None)
                    elif param == 'seq_length':
                        # Extract the individual sequence length values and add them as separate columns
                        seq_dict = config[param]
                        hyperparameters["Seq_1D"] = seq_dict.get('1D', None)
                        hyperparameters["Seq_1H"] = seq_dict.get('1H', None)
                    else:
                        # Add the parameter value to the dictionary
                        hyperparameters[param] = config[param]
            # Add the folder name as a new column in the dictionary
            hyperparameters["Model"] = folder_name
            # Append the dictionary to the list of results
            hyperparameters_list.append(hyperparameters)
        except Exception as e:
            print(f"Error occurred for params {folder_name}: {e}")
            continue  # continue to the next set of hyperparameters

# Convert the list of dictionaries to a DataFrame
df_H = pd.DataFrame(hyperparameters_list)

# Create an empty dataframe to store the results
df_V = pd.DataFrame()

# Iterate through all the subfolders in the parent directory
for folder in os.listdir(parent_dir):
    folder_path = os.path.join(parent_dir, folder)
    if os.path.isdir(folder_path):
        print("Processing folder:", folder_path)
        
        # Navigate to the validation_results.p file
        validation_path = os.path.join(folder_path, "validation", "model_epoch050", "validation_results.p")
        try:
            results = {}
            output_results = {}
            # Load the validation results
            with open(validation_path, "rb") as f:
                results = pickle.load(f)

                # Store the results in the result dictionary with the params as the key
                output_results[folder] = results  

                # Loop through each set of hyperparameters
                for params, metrics in output_results.items():
                    # Loop through each basin and frequency
                    for basin, freq_metrics in metrics.items():
                        for freq, metric_values in freq_metrics.items():
                            # Ignore the xr key and extract the other metrics
                            metrics_dict = {k:v for k,v in metric_values.items() if k != 'xr'}
                            
                            # Append the metrics and hyperparameters to the dataframe
                            row_dict = {'basin': basin, 'freq': freq, 'Model': params, **metrics_dict}
                            df_V = pd.concat([df_V, pd.DataFrame([row_dict])], ignore_index=True)
#                            df_V = df_V.append(row_dict, ignore_index=True)
                        
                # Delete the results object from memory to free up space
                del results
                del output_results

        except Exception as e:
            print(f"Error occurred for params {folder}: {e}")
            continue  # continue to the next set of hyperparameters

# Merge columns with the same name prefix, keeping non-NaN values
df_new = df_V.groupby(df_V.columns.str.replace('_1H|_1D', '', regex=True), axis=1).apply(lambda x: x.ffill(axis=1).iloc[:, -1]).astype(str)

# Rename the columns to remove the '_1H' and '_1D' suffixes
df_new.columns = df_new.columns.astype(str).str.rstrip('_1H').str.rstrip('_1D')

# Merge the two DataFrames based on the "folder_name" column
df_merged = pd.merge(df_H, df_new, on="Model")

df_merged['Model'] = df_merged['Model'].str.replace("Hypertuning_URA40Basins_", "").str.replace("_", "")

column_order = ['Seq_1D', 'Seq_1H', 'batch_size', 'target_noise_std', 'Lr0', 'Lr10', 'Lr25', 'loss', 'hidden_size',
                'output_dropout', 'initial_forget_bias', 'regularization', 'seed', 'Model', 'basin', 'freq', 
                'streamflowmean_NSE', 'levelmean_NSE', 'streamflowinst_NSE', 'levelinst_NSE',
                'streamflowmean_KGE', 'levelmean_KGE', 'streamflowinst_KGE', 'levelinst_KGE']

# Define the mapping from old names to new names
column_mapping = {
    'streamflowmean_NSE': 'SFmean_NSE',
    'levelmean_NSE': 'WLmean_NSE',
    'streamflowinst_NSE': 'SFinst_NSE',
    'levelinst_NSE': 'WLinst_NSE',
    'streamflowmean_KGE': 'SFmean_KGE',
    'levelmean_KGE': 'WLmean_KGE',
    'streamflowinst_KGE': 'SFinst_KGE',
    'levelinst_KGE': 'WLinst_KGE'
}

df_merged = df_merged[column_order].rename(columns=column_mapping)

# Save the merged DataFrame to a new CSV file
df_merged.to_csv(results_dir /"merged_results.csv", index=False)
# Out:
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0105_011029
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0105_042308
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0105_073435
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0105_104537
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0105_135823
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0105_151827
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0105_163808
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0105_235220
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0108_004247
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0108_004814
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0108_024556
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0108_030807
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0108_050356
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0108_072903
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0205_011029
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0805_145217
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0805_160253
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0805_172112
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0805_190641
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0805_201646
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0805_222133
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0805_234036
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0808_123138
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0808_124127
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0808_143713
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0808_164801
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0808_165748
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0808_191423
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0808_202911
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0808_212829
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0808_222029
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0808_232933
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_005540
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_021459
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_033158
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_044857
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_064637
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_092944
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_111556
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_125336
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_140944
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_155712
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_173347
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_194446
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_205032
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_220309
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0905_233132
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_004510
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_022915
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_023530
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_044901
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_051240
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_070526
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_070935
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_090837
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_094117
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_110638
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_122748
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_133015
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_142004
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_151620
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_163455
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_181450
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_183852
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_210420
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_211058
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_0908_230846
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1005_005411
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1005_022449
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1005_042102
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1005_061621
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1005_083328
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1005_101004
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1005_121111
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1005_142928
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_000500
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_012129
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_031823
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_040851
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_061024
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_062331
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_083535
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_090324
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_104629
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_121310
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_124856
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_140502
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_143249
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_161956
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_170323
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_193319
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_201543
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_214707
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1008_221044
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_000529
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_004011
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_015116
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_031353
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_035909
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_053403
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_054237
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_075452
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_082246
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_102907
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_111149
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_130108
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_133404
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_155505
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_160000
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_174731
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_175732
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_194812
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_202004
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_220501
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_224759
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1108_235204
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_020057
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_023956
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_040824
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_052730
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_055939
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_072941
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_081301
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_092720
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_102005
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_121544
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_123050
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_142421
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_153524
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_163205
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_172955
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_193839
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_210135
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_215436
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1208_225504
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_001559
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_005320
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_030316
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_035812
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_053342
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_065547
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_085958
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_092610
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_111556
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_113623
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_135821
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_142418
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_163841
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_172158
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_183840
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_204126
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_205705
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_224926
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1308_225150
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_010711
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_015825
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_043137
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_055326
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_071538
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_075742
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_090949
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_095108
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_113825
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_120045
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_134835
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_145006
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_164359
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_164614
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_190044
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_190652
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_214313
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_224622
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1408_235850
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_010313
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_015650
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_025047
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_035542
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_043453
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_064633
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_072248
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_091755
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_101430
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_110139
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_122337
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_132731
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_144744
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_152045
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_165906
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_172250
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_190315
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_192727
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_212733
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1508_223021
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_002243
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_004130
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_025141
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_030523
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_043609
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_050411
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_065624
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_070419
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_085448
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_092902
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_112033
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_112558
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_131924
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_140343
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_155514
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_160856
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_184033
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_203500
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_204529
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_230744
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1608_233936
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_013110
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_014452
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_034518
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_041920
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_060359
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_070809
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_081732
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_090941
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_101122
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_104925
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_125312
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_131229
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_152243
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_173509
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_173512
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_194841
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_203006
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_215637
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_232434
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1708_235511
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_014014
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_015111
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_041118
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_060536
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_080653
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_081648
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_102110
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_102423
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_121645
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_123128
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_145357
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_151235
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_165447
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_191837
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_192306
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_211955
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1808_214413
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_002607
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_010529
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_031551
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_032638
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_051646
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_093820
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_093821
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_115030
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_122043
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_134945
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_142509
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_163220
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_163826
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_184049
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_205136
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_210338
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_225348
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_1908_231012
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_010344
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_011941
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_033520
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_042735
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_054234
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_075124
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_082456
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_095552
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_105327
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_124431
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_130710
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_152335
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_162710
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_175336
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_200553
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_204655
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_222511
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2008_233259
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_021652
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_021756
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_041348
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_054321
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_061434
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_085045
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_085859
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_103618
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_105805
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_123922
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_152305
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_152814
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_175350
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_185345
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_203242
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_210240
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_224924
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2108_225225
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_003627
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_003635
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_024727
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_030634
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_050421
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_051611
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_064343
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_065548
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_090628
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_102425
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_105929
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_123502
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_141005
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_145123
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_162047
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_203845
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_203847
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_225840
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2208_230113
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_010105
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_010111
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_031246
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_034547
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_074224
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_074733
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_093428
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_094458
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_125104
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_125703
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_145032
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_150125
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_164854
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_171100
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_184751
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_200946
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_205038
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_224535
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2308_224928
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2407_123432
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2407_123434
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2407_143328
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2407_145317
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2407_172711
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2407_185052
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2407_192914
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2407_204429
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2407_222939
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2407_225408
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2408_005852
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2408_011249
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2408_033604
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2408_034314
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2408_053335
# ...
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2708_223509
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_000800
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_012925
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_033309
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_054626
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_075452
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_114337
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_133221
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_145120
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_161205
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_180425
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_195242
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_212959
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2804_233512
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_014656
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_015357
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_040343
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_040446
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_054722
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_064354
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_074445
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_090421
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_095635
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_120929
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_122044
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_141312
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_141344
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_162416
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_174201
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_182552
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_193920
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_202120
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_214823
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2807_224240
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2808_001032
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2808_004344
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2808_020247
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2808_023338
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2808_035523
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2808_044804
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2808_063354
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2808_071344
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2808_090934
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2808_094043
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2808_114203
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2808_115555
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2904_074733
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2904_104822
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2904_143450
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2904_154839
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2904_170540
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2904_181815
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2904_194008
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2904_210252
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2904_231909
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_023439
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_031846
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_050723
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_053009
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_072523
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_084842
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_091049
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_105654
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_111024
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_133032
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_145231
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_152048
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_170310
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_191236
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_195908
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_213503
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_2907_221357
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3004_040307
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3004_061929
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3004_083504
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3004_114343
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3004_145131
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3004_163217
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3004_181844
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3004_233809
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_000428
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_003526
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_015320
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_032232
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_035849
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_052755
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_055010
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_075405
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_080806
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_095540
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_100701
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_120158
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_120348
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_141119
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_142526
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_163608
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_165230
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_185739
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_192229
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_203800
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_211300
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_223521
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3007_233305
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_002358
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_013941
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_035411
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_054811
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_061251
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_082345
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_085748
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_112133
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_132247
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_142054
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_153713
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_164121
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_194544
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_202900
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_214858
# Processing folder: D:\Experiments\Hypertuning\URA_dataset\1000mtsModels_SHPsT_Process\Hypertuning\Hypertuning_URA40Basins_3107_222043

# %%
"""
=================== Removing outliers ===================
We manually removed configurations having overall average performance metrics less than 0.5 from the post-Random Search DATASET (including 24 Configs)
"""

# List of basin names to remove
models_to_remove = [
    '105042308',
    '908004510',
    '1008124856',
    '1108220501',
    '1408071538',
    '1708101122',
    '1908031551',
    '2008175336',
    '2108085859',
    '2408170627',
    '2508212427',
    '2607001222',
    '2608143652',
    '2608163243',
    '2608193453',
    '2704192907',
    '2708194303',
    '2708203837',
    '2807141344',
    '2904210252',
    '3004145131',
    '3007100701',
    '3007141119',
    '3107202900'
] # These are models that had average metrics on all URA basins < 0.5

# Filter the DataFrame to keep rows where the "basin" column is NOT in the specified list
filtered_df = df_merged[~df_merged['Model'].isin(models_to_remove)]

# List of basin names to remove (The ones that do not have verification data)
basins_to_remove = [
    'Abetxuko', 'Alegria', 'Araxes', 'Areta', 'Eibar',
    'Etura', 'Gatika', 'Jaizubia', 'Larrainazubi', 'Markina',
    'Ozaeta', 'Arenao', 'SanPrudentzio', 'Ibaieder', 'Sodupe'
] # These are basins that we decided to remove from verification checkup due to data deficiencies (only 25 out of 40 basins where considered to decide on the best configuration post-Random Search)

# Filter the DataFrame to keep rows where the "basin" column is NOT in the specified list
filtered_df = filtered_df[~filtered_df['basin'].isin(basins_to_remove)]

# Save the filtered DataFrame to a new CSV file
filtered_df.to_csv(os.path.join(results_dir, "_merged_results_DeepCleaned_All.csv"), index=False)

# %%
"""
=================== To make SHPsT outcome, regionally out of basin scale ===================
"""

input_file_path = r'...\Supplementary_materials\Results\merged_results_DeepCleaned_All.csv'
data = pd.read_csv(input_file_path)
grouped_data = data.groupby(['Model', 'freq']).mean().reset_index()

column_order = ['Seq_1D', 'Seq_1H', 'batch_size', 'target_noise_std', 'Lr0', 'Lr10', 'Lr25', 'loss', 'hidden_size',
                'output_dropout', 'initial_forget_bias', 'regularization', 'seed', 'Model', 'freq', 
                'SFmean_NSE', 'WLmean_NSE', 'SFinst_NSE', 'WLinst_NSE', 'SFmean_KGE', 'WLmean_KGE', 'SFinst_KGE', 'WLinst_KGE']

grouped_data = grouped_data[column_order]

output_file_path = r'...\Supplementary_materials\Results\URA__merged_results_DeepCleaned_All.csv'
grouped_data.to_csv(output_file_path, index=False)
# Out:
# C:\Users\hosseinifh\AppData\Local\Temp\ipykernel_3828\2400276150.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_data = data.groupby(['Model', 'freq']).mean().reset_index()

# %% [markdown]
# ## Choose the best-performing LSTM networks regarding their overall regional perofrmance NSE and KGE metrics after 100 (RO) and 1000 (ERO) random search
#
# ## Update configurations and generate 10 configs for each network regarding 10 different random seeds:

# %%
"""
Updating Configs for best performing HPs after 100 and 1000 Random Searches
"""

# Paths
csv_path = r'...\Supplementary_materials\Results\Hyperparameters_configuration_selected.csv'
output_config_folder = r'...\Supplementary_materials\RO_ERO_configs'

# Create the output folder if it doesn't exist
os.makedirs(output_config_folder, exist_ok=True)

# Load CSV data
csv_data = pd.read_csv(csv_path)

# Read the original config
original_config = yaml.load(Path("config_mts_LSTM.yml").read_text(), Loader=yaml.SafeLoader)

# Seeds to use
seeds = [893856, 202981, 970216, 723952, 931334, 846266, 339685, 64410, 105209, 370654]

# Iterate through rows of the CSV and update specific sections in the config
for index, row in csv_data.iterrows():
    for seed in seeds:
        # Create a new config based on the original config
        updated_config = original_config.copy()
        
        # Update seed value
        updated_config['seed'] = seed

        # Update specific sections with values from the CSV row
        updated_config['seq_length'] = {
            '1D': row['Seq_1D'],
            '1H': row['Seq_1H']
        }
        updated_config['batch_size'] = row['batch_size']
        updated_config['target_noise_std'] = row['target_noise_std']
        updated_config['learning_rate'] = {
            0: row['Lr0'],
            10: row['Lr10'],
            25: row['Lr25']
        }
        updated_config['loss'] = row['loss']
        updated_config['hidden_size'] = row['hidden_size']
        updated_config['output_dropout'] = row['output_dropout']
        updated_config['initial_forget_bias'] = row['initial_forget_bias']
        updated_config['regularization'] = [row['regularization']]
        updated_config['run_dir'] = f'runs/train_test/{row["name"]}'
        updated_config['experiment_name'] = row['name']

        # Generate the model name based on the "model" column
        model_name = f"{row['name']}_seed_{seed}"

        # Save the updated config to a new YAML file
        output_config_file = os.path.join(output_config_folder, f'{model_name}_config.yml')
        with open(output_config_file, 'w') as out_config_file:
            yaml.dump(updated_config, out_config_file, default_flow_style=False)

print("Updated configs have been saved.")
# Out:
# Updated configs have been saved.

# %%
"""
============= Code to Run multiple retrainings in parallel for RO and ERO final hyper-tuned networks by NeuralHydrology Python library ===================
"""

config_folder = Path("RO_ERO_configs")

# Set the mode, directory, GPU IDs, and runs per GPU
mode = "train"
directory = config_folder
gpu_ids = [0, 1]  # List of GPU IDs to use (We had 2 GPUs cluster with 7 CPUs)
runs_per_gpu = 5  # Number of runs to start on a single GPU depending on the resources. We could not increase to more than 5.

try:
    # Call the schedule_runs function
    schedule_runs(mode, directory, gpu_ids, runs_per_gpu)

except Exception as e:
    print(f"An error occurred during execution: {e}")

# %%
"""
============= To load all Training Folders for RO and ERO networks and Test them on test set =============
            We will have 80 final fully trained/tested models ensembles
"""

# Define the parent directory that contains the folders with config files
parent_dir_cluster = r"...\Supplementary_materials\trained_models\RO_after_100RandomSearch" # or \ERO_after_1000RandomSearch

for folder_name in os.listdir(parent_dir_cluster):
    # Create the path to the folder
    folder_path = os.path.join(parent_dir_cluster, folder_name)
    # Check if the path is a directory
    if os.path.isdir(folder_path):
        try:
            run_config_path = os.path.join(folder_path, "config.yml")

            # Load the config.yml file
            with open(run_config_path, 'r') as file:
                run_config = yaml.safe_load(file)

            # Create an instance of the Config class
            cfg = Config(run_config)

            # create a tester instance and start evaluation
            tester = get_tester(cfg=cfg, run_dir=Path(folder_path), period="test", init_model=True)
            results = tester.evaluate(save_results=True, metrics=cfg.metrics)

            results.keys()

            print("Folder name:", folder_name)
            print("Config file path:", run_config_path)

        except Exception as e:
            print(f"Error occurred for folder {folder_name}: {e}")
            continue  # continue to the next folder

# %%
"""
=================== After All Tests finished, we want to make output results file ===================
            Extracting Hyperparameters and test metrics for RO and ERO trained/tested models
"""

parent_dir = r"...\Supplementary_materials\trained_models\ERO_after_1000RandomSearch"
# parent_dir = r"D:\Thesis2024\Papers.OnGoing\Papers.UnderWork\Paper.01.01.RandomSearch.SHpT.URA\Supplementary_materials\trained_models\RO_after_100RandomSearch"

# Set the directory for the results
results_dir = Path(r'...\Supplementary_materials\Results')

# Define the list of parameters to extract from the config files
params = {
    'hidden_size',
    'initial_forget_bias',
    'output_dropout',
    'batch_size',
    'learning_rate',
    'target_noise_std',
    'regularization',
    'seq_length',
    'loss',
    'seed'
}

# Create an empty dictionary to store the results
hyperparameters_list = []

# Iterate over the folders in the parent directory
for folder_name in os.listdir(parent_dir):
    # Create the path to the folder
    folder_path = os.path.join(parent_dir, folder_name)
    # Check if the path is a directory
    if os.path.isdir(folder_path):
        # Create an empty dictionary to store the hyperparameters for this folder
        hyperparameters = {}
        # Read the config file for this folder
        try:
            config_path = os.path.join(folder_path, "config.yml")
            with open(config_path, "r") as f:
                config = yaml.safe_load(f)
            # Extract the relevant hyperparameters from the config file
            for param in params:
                if param in config:
                    if param == 'learning_rate':
                        # Extract the individual learning rate values and add them as separate columns
                        lr_dict = config[param]
                        hyperparameters["Lr0"] = lr_dict.get(0, None)
                        hyperparameters["Lr10"] = lr_dict.get(10, None)
                        hyperparameters["Lr25"] = lr_dict.get(25, None)
                    elif param == 'seq_length':
                        # Extract the individual sequence length values and add them as separate columns
                        seq_dict = config[param]
                        hyperparameters["Seq_1D"] = seq_dict.get('1D', None)
                        hyperparameters["Seq_1H"] = seq_dict.get('1H', None)
                    else:
                        # Add the parameter value to the dictionary
                        hyperparameters[param] = config[param]
            # Add the folder name as a new column in the dictionary
            hyperparameters["Model"] = folder_name
            # Append the dictionary to the list of results
            hyperparameters_list.append(hyperparameters)
        except Exception as e:
            print(f"Error occurred for params {folder_name}: {e}")
            continue  # continue to the next set of hyperparameters

# Convert the list of dictionaries to a DataFrame
df_H = pd.DataFrame(hyperparameters_list)

# Create an empty dataframe to store the results
df_V = pd.DataFrame()

# Iterate through all the subfolders in the parent directory
for folder in os.listdir(parent_dir):
    folder_path = os.path.join(parent_dir, folder)
    if os.path.isdir(folder_path):
        print("Processing folder:", folder_path)
        
        # Navigate to the test_results.p file
        test_folder = os.path.join(folder_path, "test")
        for folder_test in os.listdir(test_folder):
            test_path = os.path.join(folder_path, "test", folder_test, "test_results.p")
        try:
            results = {}
            output_results = {}
            # Load the validation results
            with open(test_path, "rb") as f:
                # results = pickle.load(f)
                results = pd.read_pickle(f)
                # Store the results in the result dictionary with the params as the key
                output_results[folder] = results  

                # Loop through each set of hyperparameters
                for params, metrics in output_results.items():
                    # Loop through each basin and frequency
                    for basin, freq_metrics in metrics.items():
                        for freq, metric_values in freq_metrics.items():
                            # Ignore the xr key and extract the other metrics
                            metrics_dict = {k:v for k,v in metric_values.items() if k != 'xr'}
                            
                            # Append the metrics and hyperparameters to the dataframe
                            row_dict = {'basin': basin, 'freq': freq, 'Model': params, **metrics_dict}
                            df_V = pd.concat([df_V, pd.DataFrame([row_dict])], ignore_index=True)
                        
                # Delete the results object from memory to free up space
                del results
                del output_results

        except Exception as e:
            print(f"Error occurred for params {folder}: {e}")
            continue  # continue to the next set of hyperparameters

# Rename the columns to remove the '_1H' and '_1D' suffixes
df_V.columns = df_V.columns.astype(str).str.rstrip('_1H').str.rstrip('_1D')

# Merge columns with the same name prefix, keeping non-NaN values
df_new = df_V.groupby(df_V.columns.str.replace('_1H|_1D', '', regex=True), axis=1).apply(lambda x: x.ffill(axis=1).iloc[:, -1]).astype(str)

# Merge the two DataFrames based on the "folder_name" column
df_merged = pd.merge(df_H, df_new, on="Model")

column_order = ['Seq_1D', 'Seq_1H', 'batch_size', 'target_noise_std', 'Lr0', 'Lr10', 'Lr25', 'loss', 'hidden_size',
                'output_dropout', 'initial_forget_bias', 'regularization', 'seed', 'Model', 'basin', 'freq', 
                'streamflowmean_NSE',       'levelmean_NSE',        'streamflowinst_NSE',       'levelinst_NSE', 
                'streamflowmean_KGE',       'levelmean_KGE',        'streamflowinst_KGE',       'levelinst_KGE', 
                'streamflowmean_MSE',       'levelmean_MSE',        'streamflowinst_MSE',       'levelinst_MSE',
                'streamflowmean_RMSE',      'levelmean_RMSE',       'streamflowinst_RMSE',      'levelinst_RMSE', 
                'streamflowmean_Alpha-NSE', 'levelmean_Alpha-NSE',  'streamflowinst_Alpha-NSE', 'levelinst_Alpha-NSE', 
                'streamflowmean_Beta-NSE',  'levelmean_Beta-NSE',   'streamflowinst_Beta-NSE',  'levelinst_Beta-NSE',
                'streamflowmean_Pearson-r', 'levelmean_Pearson-r',  'streamflowinst_Pearson-r', 'levelinst_Pearson-r', 
                'streamflowmean_Beta-KGE',  'levelmean_Beta-KGE',   'streamflowinst_Beta-KGE',  'levelinst_Beta-KGE', 
                'streamflowmean_FHV',       'levelmean_FHV',        'streamflowinst_FHV',       'levelinst_FHV',
                'streamflowmean_FMS',       'levelmean_FMS',        'streamflowinst_FMS',       'levelinst_FMS', 
                'streamflowmean_FLV',       'levelmean_FLV',        'streamflowinst_FLV',       'levelinst_FLV', 
                'streamflowmean_Peak-Timing','levelmean_Peak-Timing', 'streamflowinst_Peak-Timing', 'levelinst_Peak-Timing',
                'streamflowmean_Peak-MAPE', 'levelmean_Peak-MAPE',  'streamflowinst_Peak-MAPE', 'levelinst_Peak-MAPE',
                'streamflowmean_Missed-Peaks', 'levelmean_Missed-Peaks',  'streamflowinst_Missed-Peaks', 'levelinst_Missed-Peaks']

# Define the mapping from old names to new names
column_mapping = {
    'streamflowmean_NSE': 'SFmean_NSE',
    'levelmean_NSE': 'WLmean_NSE',
    'streamflowinst_NSE': 'SFinst_NSE',
    'levelinst_NSE': 'WLinst_NSE',
    'streamflowmean_KGE': 'SFmean_KGE',
    'levelmean_KGE': 'WLmean_KGE',
    'streamflowinst_KGE': 'SFinst_KGE',
    'levelinst_KGE': 'WLinst_KGE',
    'streamflowmean_MSE': 'SFmean_MSE',
    'levelmean_MSE': 'WLmean_MSE',
    'streamflowinst_MSE': 'SFinst_MSE',
    'levelinst_MSE': 'WLinst_MSE',
    'streamflowmean_RMSE': 'SFmean_RMSE',
    'levelmean_RMSE': 'WLmean_RMSE',
    'streamflowinst_RMSE': 'SFinst_RMSE',
    'levelinst_RMSE': 'WLinst_RMSE',
    'streamflowmean_Alpha-NSE': 'SFmean_Alpha-NSE',
    'levelmean_Alpha-NSE': 'WLmean_Alpha-NSE',
    'streamflowinst_Alpha-NSE': 'SFinst_Alpha-NSE',
    'levelinst_Alpha-NSE': 'WLinst_Alpha-NSE',
    'streamflowmean_Beta-NSE': 'SFmean_Beta-NSE',
    'levelmean_Beta-NSE': 'WLmean_Beta-NSE',
    'streamflowinst_Beta-NSE': 'SFinst_Beta-NSE',
    'levelinst_Beta-NSE': 'WLinst_Beta-NSE',
    'streamflowmean_Pearson-r': 'SFmean_Pearson-r',
    'levelmean_Pearson-r': 'WLmean_Pearson-r',
    'streamflowinst_Pearson-r': 'SFinst_Pearson-r',
    'levelinst_Pearson-r': 'WLinst_Pearson-r',
    'streamflowmean_Beta-KGE': 'SFmean_Beta-KGE',
    'levelmean_Beta-KGE': 'WLmean_Beta-KGE',
    'streamflowinst_Beta-KGE': 'SFinst_Beta-KGE',
    'levelinst_Beta-KGE': 'WLinst_Beta-KGE',
    'streamflowmean_FHV': 'SFmean_FHV',
    'levelmean_FHV': 'WLmean_FHV',
    'streamflowinst_FHV': 'SFinst_FHV',
    'levelinst_FHV': 'WLinst_FHV',
    'streamflowmean_FMS': 'SFmean_FMS',
    'levelmean_FMS': 'WLmean_FMS',
    'streamflowinst_FMS': 'SFinst_FMS',
    'levelinst_FMS': 'WLinst_FMS',
    'streamflowmean_FLV': 'SFmean_FLV',
    'levelmean_FLV': 'WLmean_FLV',
    'streamflowinst_FLV': 'SFinst_FLV',
    'levelinst_FLV': 'WLinst_FLV',
    'streamflowmean_Peak-Timing': 'SFmean_Peak-Timing',
    'levelmean_Peak-Timing': 'WLmean_Peak-Timing',
    'streamflowinst_Peak-Timing': 'SFinst_Peak-Timing',
    'levelinst_Peak-Timing': 'WLinst_Peak-Timing',
    'streamflowmean_Peak-MAPE': 'SFmean_Peak-MAPE',
    'levelmean_Peak-MAPE': 'WLmean_Peak-MAPE',
    'streamflowinst_Peak-MAPE': 'SFinst_Peak-MAPE',
    'levelinst_Peak-MAPE': 'WLinst_Peak-MAPE',
    'streamflowmean_Missed-Peaks': 'SFmean_Missed-Peaks',
    'levelmean_Missed-Peaks': 'WLmean_Missed-Peaks',
    'streamflowinst_Missed-Peaks': 'SFinst_Missed-Peaks',
    'levelinst_Missed-Peaks': 'WLinst_Missed-Peaks'
}

df_merged = df_merged[column_order].rename(columns=column_mapping)
df_merged["Model"] = df_merged["Model"].str.replace("One_Fits_All_1000_", "").str.replace("_", "")

# Save the merged DataFrame to a new CSV file
df_merged.to_csv(results_dir /"ERO.metrics.csv", index=False)
# df_merged.to_csv(results_dir /"RO.metrics.csv", index=False)
# Out:
# Processing folder: D:\Thesis2024\Papers.OnGoing\Papers.UnderWork\Paper.01.01.RandomSearch.SHpT.URA\Supplementary_materials\trained_models\ERO_after_1000RandomSearch\Models_Overfitting_Checked\One_Fits_All_1000_1201_123344
# Processing folder: D:\Thesis2024\Papers.OnGoing\Papers.UnderWork\Paper.01.01.RandomSearch.SHpT.URA\Supplementary_materials\trained_models\ERO_after_1000RandomSearch\Models_Overfitting_Checked\One_Fits_All_1000_1201_123349
# Processing folder: D:\Thesis2024\Papers.OnGoing\Papers.UnderWork\Paper.01.01.RandomSearch.SHpT.URA\Supplementary_materials\trained_models\ERO_after_1000RandomSearch\Models_Overfitting_Checked\One_Fits_All_1000_1201_123402
# Processing folder: D:\Thesis2024\Papers.OnGoing\Papers.UnderWork\Paper.01.01.RandomSearch.SHpT.URA\Supplementary_materials\trained_models\ERO_after_1000RandomSearch\Models_Overfitting_Checked\One_Fits_All_1000_1201_123411
# Processing folder: D:\Thesis2024\Papers.OnGoing\Papers.UnderWork\Paper.01.01.RandomSearch.SHpT.URA\Supplementary_materials\trained_models\ERO_after_1000RandomSearch\Models_Overfitting_Checked\One_Fits_All_1000_1201_123413
# Processing folder: D:\Thesis2024\Papers.OnGoing\Papers.UnderWork\Paper.01.01.RandomSearch.SHpT.URA\Supplementary_materials\trained_models\ERO_after_1000RandomSearch\Models_Overfitting_Checked\One_Fits_All_1000_1201_123425
# Processing folder: D:\Thesis2024\Papers.OnGoing\Papers.UnderWork\Paper.01.01.RandomSearch.SHpT.URA\Supplementary_materials\trained_models\ERO_after_1000RandomSearch\Models_Overfitting_Checked\One_Fits_All_1000_1901_103552
# Processing folder: D:\Thesis2024\Papers.OnGoing\Papers.UnderWork\Paper.01.01.RandomSearch.SHpT.URA\Supplementary_materials\trained_models\ERO_after_1000RandomSearch\Models_Overfitting_Checked\One_Fits_All_1000_1901_103554
# Processing folder: D:\Thesis2024\Papers.OnGoing\Papers.UnderWork\Paper.01.01.RandomSearch.SHpT.URA\Supplementary_materials\trained_models\ERO_after_1000RandomSearch\Models_Overfitting_Checked\One_Fits_All_1000_1901_103556
# Processing folder: D:\Thesis2024\Papers.OnGoing\Papers.UnderWork\Paper.01.01.RandomSearch.SHpT.URA\Supplementary_materials\trained_models\ERO_after_1000RandomSearch\Models_Overfitting_Checked\One_Fits_All_1000_1901_103603

# %% [markdown]
# ## Processing the results can be found on the other code in Supplementary_materials named: "Master_Experiment_4Paper.RandomSearch.SHpT.URA"
